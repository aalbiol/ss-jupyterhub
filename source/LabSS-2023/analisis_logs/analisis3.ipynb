# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import loganalisis
from glob import glob
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fichero = "/srv/log/users/profesor.log"

# %%
res=loganalisis.resumen(fichero)

# %%
for k,v in res.items():
    print(k, ' : ')
    print(v)
    print("==========================")
# Out:
# 01-read_and_info  :
# {'num_sesiones': 3, 'min_totales': 2, 'ntesting': 124, 'nsuccess': 81}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 0, 'ntesting': 5, 'nsuccess': 5}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 0, 'ntesting': 10, 'nsuccess': 11}
# ==========================

# %%
ficheros=glob("/srv/log/users/*.log")

# %%
for f in ficheros:
    user=f.split("/")[-1]
    user=user.split(".")[0]
    print(user,"#############################################")
    res=loganalisis.resumen(f)
    for k,v in res.items():
        print(k, ' : ')
        print(v)
        print("==========================")
# Out:
# spuerob #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 108, 'ntesting': 61, 'nsuccess': 36}
# ==========================
# 03-juntando  :
# {'num_sesiones': 2, 'min_totales': 50, 'ntesting': 24, 'nsuccess': 18}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 96, 'ntesting': 67, 'nsuccess': 66}
# ==========================
# rlosbes #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 71, 'ntesting': 22, 'nsuccess': 14}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 52, 'ntesting': 31, 'nsuccess': 8}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 71, 'ntesting': 48, 'nsuccess': 33}
# ==========================
# pmatbol #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 90, 'ntesting': 28, 'nsuccess': 5}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 22, 'ntesting': 6, 'nsuccess': 6}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 54, 'ntesting': 16, 'nsuccess': 9}
# ==========================
# jcebmir #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 77, 'ntesting': 15, 'nsuccess': 4}
# ==========================
# cbencan #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 48, 'ntesting': 10, 'nsuccess': 6}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 0, 'ntesting': 0, 'nsuccess': 0}
# ==========================
# vzarher #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 86, 'ntesting': 16, 'nsuccess': 6}
# ==========================
# asancan2 #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 90, 'ntesting': 26, 'nsuccess': 7}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 35, 'ntesting': 10, 'nsuccess': 4}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 60, 'ntesting': 48, 'nsuccess': 49}
# ==========================
# sruiper #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 13, 'ntesting': 7, 'nsuccess': 3}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 22, 'ntesting': 3, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 57, 'ntesting': 10, 'nsuccess': 10}
# ==========================
# fjgombaq #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 38, 'ntesting': 27, 'nsuccess': 17}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 47, 'ntesting': 15, 'nsuccess': 6}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 54, 'ntesting': 19, 'nsuccess': 14}
# ==========================
# jvolmalb #############################################
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 49, 'ntesting': 8, 'nsuccess': 6}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 118, 'ntesting': 16, 'nsuccess': 10}
# ==========================
# rsissan #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 52, 'ntesting': 19, 'nsuccess': 2}
# ==========================
# aibacol #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 45, 'ntesting': 33, 'nsuccess': 11}
# ==========================
# 03-juntando  :
# {'num_sesiones': 2, 'min_totales': 40, 'ntesting': 22, 'nsuccess': 19}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 54, 'ntesting': 37, 'nsuccess': 27}
# ==========================
# clase #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 85, 'ntesting': 11, 'nsuccess': 2}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 31, 'ntesting': 5, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 59, 'ntesting': 14, 'nsuccess': 17}
# ==========================
# amiqfus #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 85, 'ntesting': 8, 'nsuccess': 6}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 34, 'ntesting': 12, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 116, 'ntesting': 28, 'nsuccess': 26}
# ==========================
# fcargra #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 43, 'ntesting': 13, 'nsuccess': 6}
# ==========================
# ajimcas #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 89, 'ntesting': 68, 'nsuccess': 9}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 20, 'ntesting': 14, 'nsuccess': 8}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 84, 'ntesting': 22, 'nsuccess': 12}
# ==========================
# iferjua #############################################
# 01-read_and_info  :
# {'num_sesiones': 3, 'min_totales': 58, 'ntesting': 36, 'nsuccess': 11}
# ==========================
# 03-juntando  :
# {'num_sesiones': 2, 'min_totales': 62, 'ntesting': 49, 'nsuccess': 22}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 94, 'ntesting': 55, 'nsuccess': 42}
# ==========================
# jvilsel #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 38, 'ntesting': 30, 'nsuccess': 3}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 35, 'ntesting': 6, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 56, 'ntesting': 22, 'nsuccess': 13}
# ==========================
# aguialf #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 40, 'ntesting': 35, 'nsuccess': 10}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 41, 'ntesting': 21, 'nsuccess': 4}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 75, 'ntesting': 32, 'nsuccess': 33}
# ==========================
# rrieagu #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 50, 'ntesting': 29, 'nsuccess': 4}
# ==========================
# 03-juntando  :
# {'num_sesiones': 2, 'min_totales': 20, 'ntesting': 7, 'nsuccess': 6}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 87, 'ntesting': 61, 'nsuccess': 55}
# ==========================
# jvalrod #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 29, 'ntesting': 23, 'nsuccess': 14}
# ==========================
# 03-juntando  :
# {'num_sesiones': 2, 'min_totales': 8, 'ntesting': 11, 'nsuccess': 11}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 164, 'ntesting': 45, 'nsuccess': 45}
# ==========================
# storram #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 90, 'ntesting': 43, 'nsuccess': 8}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 32, 'ntesting': 19, 'nsuccess': 9}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 67, 'ntesting': 15, 'nsuccess': 16}
# ==========================
# acammor1 #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 90, 'ntesting': 21, 'nsuccess': 7}
# ==========================
# xblagon #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 87, 'ntesting': 28, 'nsuccess': 15}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 35, 'ntesting': 20, 'nsuccess': 6}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 72, 'ntesting': 33, 'nsuccess': 28}
# ==========================
# jviltor2 #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 16, 'ntesting': 4, 'nsuccess': 0}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 33, 'ntesting': 5, 'nsuccess': 2}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 48, 'ntesting': 5, 'nsuccess': 4}
# ==========================
# pdomzur #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 41, 'ntesting': 2, 'nsuccess': 0}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 22, 'ntesting': 3, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 52, 'ntesting': 11, 'nsuccess': 5}
# ==========================
# jcotmar #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 0, 'ntesting': 4, 'nsuccess': 3}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 33, 'ntesting': 1, 'nsuccess': 0}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 5, 'ntesting': 11, 'nsuccess': 9}
# ==========================
# dtoribo #############################################
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 21, 'ntesting': 4, 'nsuccess': 4}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 48, 'ntesting': 7, 'nsuccess': 7}
# ==========================
# sripcig #############################################
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 48, 'ntesting': 13, 'nsuccess': 10}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 117, 'ntesting': 36, 'nsuccess': 27}
# ==========================
# profesor #############################################
# 01-read_and_info  :
# {'num_sesiones': 3, 'min_totales': 2, 'ntesting': 124, 'nsuccess': 81}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 0, 'ntesting': 5, 'nsuccess': 5}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 0, 'ntesting': 10, 'nsuccess': 11}
# ==========================
# aperlop2 #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 88, 'ntesting': 23, 'nsuccess': 11}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 22, 'ntesting': 5, 'nsuccess': 5}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 114, 'ntesting': 74, 'nsuccess': 68}
# ==========================
# lsanrub #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 39, 'ntesting': 6, 'nsuccess': 0}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 17, 'ntesting': 3, 'nsuccess': 1}
# ==========================
# 02-slicing  :
# {'num_sesiones': 3, 'min_totales': 63, 'ntesting': 12, 'nsuccess': 6}
# ==========================
# mivados #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 87, 'ntesting': 15, 'nsuccess': 9}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 31, 'ntesting': 5, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 62, 'ntesting': 10, 'nsuccess': 9}
# ==========================
# iborroi #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 88, 'ntesting': 26, 'nsuccess': 12}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 49, 'ntesting': 5, 'nsuccess': 5}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 70, 'ntesting': 72, 'nsuccess': 67}
# ==========================
# jvmorcal #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 86, 'ntesting': 15, 'nsuccess': 8}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 21, 'ntesting': 3, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 57, 'ntesting': 15, 'nsuccess': 14}
# ==========================
# abodbro #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 88, 'ntesting': 25, 'nsuccess': 20}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 32, 'ntesting': 8, 'nsuccess': 5}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 59, 'ntesting': 11, 'nsuccess': 13}
# ==========================
# jconara #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 77, 'ntesting': 21, 'nsuccess': 0}
# ==========================
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 34, 'ntesting': 4, 'nsuccess': 3}
# ==========================
# 02-slicing  :
# {'num_sesiones': 2, 'min_totales': 108, 'ntesting': 12, 'nsuccess': 11}
# ==========================
# alifriv #############################################
# 01-read_and_info  :
# {'num_sesiones': 1, 'min_totales': 87, 'ntesting': 26, 'nsuccess': 14}
# ==========================
# allovil2 #############################################
# 03-juntando  :
# {'num_sesiones': 1, 'min_totales': 49, 'ntesting': 19, 'nsuccess': 10}
# ==========================
# 02-slicing  :
# {'num_sesiones': 1, 'min_totales': 67, 'ntesting': 23, 'nsuccess': 21}
# ==========================
# idiadol #############################################
# 01-read_and_info  :
# {'num_sesiones': 2, 'min_totales': 90, 'ntesting': 36, 'nsuccess': 24}
# ==========================
# 03-juntando  :
# {'num_sesiones': 2, 'min_totales': 43, 'ntesting': 5, 'nsuccess': 4}
# ==========================
# 02-slicing  :
# {'num_sesiones': 3, 'min_totales': 313, 'ntesting': 59, 'nsuccess': 49}
# ==========================
